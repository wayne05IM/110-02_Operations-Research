# %%
import plotly.express as px
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
plt.rcParams["figure.dpi"] = 150

# %%
# create a dataframe using time with date
dl_df = pd.DataFrame([
    dict(Machine=2, Start=0, Finish=4.5, job=1),
    dict(Machine=4, Start=0, Finish=5.0, job=2),
    dict(Machine=3, Start=3.7, Finish=10.1, job=3),
    dict(Machine=5, Start=6.5, Finish=10.1, job=4),
    dict(Machine=3, Start=0, Finish=3.7, job=5),
    dict(Machine=5, Start=0, Finish=3.3, job=6),
    dict(Machine=5, Start=3.3, Finish=6.5, job=7),
    dict(Machine=2, Start=8.5, Finish=9.8, job=8),
    dict(Machine=2, Start=4.5, Finish=8.5, job=9),
    dict(Machine=4, Start=5.0, Finish=8.9, job=10),
])
dl_df['delta'] = dl_df['Finish'] - dl_df['Start']

display(dl_df)
# Out:
#    Machine  Start  Finish  job  delta
# 0        2    0.0     4.5    1    4.5
# 1        4    0.0     5.0    2    5.0
# 2        3    3.7    10.1    3    6.4
# 3        5    6.5    10.1    4    3.6
# 4        3    0.0     3.7    5    3.7
# 5        5    0.0     3.3    6    3.3
# 6        5    3.3     6.5    7    3.2
# 7        2    8.5     9.8    8    1.3
# 8        2    4.5     8.5    9    4.0
# 9        4    5.0     8.9   10    3.9

# %%
colors = ['#FF0088',
          '#FF8800',
          '#FFFF00',
          '#77FF00',
          '#00FF99',
          '#00FFFF', 
          "#0066FF",
          "#7700FF",
          '#FF00FF',
          '#DDDDDD',
          '#FFFFBB',
          '#CCCCFF']


ylist = [0, (5, 4), (10, 4), (15, 4), (20, 4), (25, 4)]

# %%
fig, ax = plt.subplots()


for i in range(dl_df.shape[0]):
    ax.broken_barh([(dl_df["Start"][i], dl_df["delta"][i])], ylist[dl_df["Machine"][i]], label=dl_df['job'][i], facecolors=colors[i])

ax.set_ylim(3, 30)
ax.set_xlim(0, 12)
ax.set_xlabel('Instance schedule')
ax.set_xticks(range(11))
ax.set_xticklabels(['7:30', '8:30', '9:30', '10:30', '11:30', '12:30', '13:30', '14:30', '15:30', '16:30', '17:30'], rotation=90)
ax.set_yticks([7,12,17,22,27])
ax.set_yticklabels(['1', '2', '3', '4', '5'])
ax.set_ylabel('Machine')
ax.grid(True)
ax.legend(loc="upper right")

plt.savefig('fig1-3.png')
